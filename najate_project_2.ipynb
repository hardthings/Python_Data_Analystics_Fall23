# %% [markdown]
# <a href="https://colab.research.google.com/github/hardthings/Python_Data_Analystics_Fall23/blob/main/najate_project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib_inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.shape
# Out:
# (101766, 50)

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %%
df. describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
df['weight'] = df['weight'].replace('?', pd.NA) #I replaced '?' with 'pd.NA'
df['race'] = df['race'].replace('?', pd.NA) #I replaced '?' with 'pd.NA'
df.head(10) #Confirming N/A has been implemented
# Out:
#    encounter_id  patient_nbr             race  gender       age weight  \
# 0       2278392      8222157        Caucasian  Female    [0-10)   <NA>
# 1        149190     55629189        Caucasian  Female   [10-20)   <NA>
# 2         64410     86047875  AfricanAmerican  Female   [20-30)   <NA>
# 3        500364     82442376        Caucasian    Male   [30-40)   <NA>
# 4         16680     42519267        Caucasian    Male   [40-50)   <NA>
# 5         35754     82637451        Caucasian    Male   [50-60)   <NA>
# 6         55842     84259809        Caucasian    Male   [60-70)   <NA>
# 7         63768    114882984        Caucasian    Male   [70-80)   <NA>
# 8         12522     48330783        Caucasian  Female   [80-90)   <NA>
# 9         15738     63555939        Caucasian  Female  [90-100)   <NA>
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# ...

# %%
df.groupby(['race'])['patient_nbr'].count().sort_values(ascending=False)
# Out:
# race
# Caucasian          76099
# AfricanAmerican    19210
# Hispanic            2037
# Other               1506
# Asian                641
# Name: patient_nbr, dtype: int64

# %%
df2=df[['patient_nbr','race','age','gender','time_in_hospital','readmitted']]
df2.head()
# Out:
#    patient_nbr             race      age  gender  time_in_hospital readmitted
# 0      8222157        Caucasian   [0-10)  Female                 1         NO
# 1     55629189        Caucasian  [10-20)  Female                 3        >30
# 2     86047875  AfricanAmerican  [20-30)  Female                 2         NO
# 3     82442376        Caucasian  [30-40)    Male                 2         NO
# 4     42519267        Caucasian  [40-50)    Male                 1         NO

# %%
hispanic=df2[df2['race']=='Hispanic']

# %%
all_races=df2[df2['race']!='Other']

# %%
asian=df2[df2['race']=='Asian']

# %%
all_races.describe()
# Out:
#         patient_nbr  time_in_hospital
# count  1.002600e+05     100260.000000
# mean   5.400272e+07          4.397826
# std    3.836611e+07          2.984272
# min    1.350000e+02          1.000000
# 25%    2.339968e+07          2.000000
# 50%    4.522226e+07          4.000000
# 75%    8.725499e+07          6.000000
# max    1.895026e+08         14.000000

# %%
hispanic.describe()
# Out:
#         patient_nbr  time_in_hospital
# count  2.037000e+03       2037.000000
# mean   6.154605e+07          4.059892
# std    4.443959e+07          2.824838
# min    1.300500e+04          1.000000
# 25%    2.359229e+07          2.000000
# 50%    5.675710e+07          3.000000
# 75%    9.584839e+07          5.000000
# max    1.887556e+08         14.000000

# %%
asian.describe()
# Out:
#         patient_nbr  time_in_hospital
# count  6.410000e+02        641.000000
# mean   7.402927e+07          3.995320
# std    4.699916e+07          2.937097
# min    1.176570e+05          1.000000
# 25%    3.518412e+07          2.000000
# 50%    7.509539e+07          3.000000
# 75%    1.033065e+08          5.000000
# max    1.893494e+08         14.000000

# %% [markdown]
# visualizationof days in hospital by race (Hispanic.Asian and all races)

# %%
sns.displot(hispanic['time_in_hospital'])
plt.title('Days in Hospital Hispanic')
plt.xlabel('Time in Hospital')
plt.ylabel('Count')
# Out:
# Text(5.069444444444445, 0.5, 'Count')

# %% [markdown]
# relation between race asian and hispanic variables

# %%
hispanic_asian = df2[df2['race'].isin(['Hispanic','Asian'])]
sns.pairplot(hispanic_asian, hue='race')

# %% [markdown]
# comparison the average time inthe hospital across different age group and races

# %%
plt.figure(figsize=(12, 8))
sns.set(font_scale=1.0)
ax=sns.barplot(data=df2, x='age', y='time_in_hospital', hue='race', palette='muted')
plt.title('Days in Hospital Comparison by Age Group and Race')
plt.xlabel('Age Group')
plt.ylabel('Time in Hospital')
plt.legend(title='Race', bbox_to_anchor=(1, 1))

# %% [markdown]
# In this project, I performed an analysis on diabetes-related with the amount of time they spend in hospital by race and age. Grouped the data by race ad checked the distribution of patients among different racial categories. Selected specific columns of interst for further analysis.
# Described the dta for all races, Hispanic indivifuals, and Asian individuals. Checked kjhospital stay distribution for Hispanic ad Asian individuals. Explored relationships jbetween variables for these groups. Compared average hospital staay across age groups and jraces. On average, people tend to be hospitalized for a shorter duration, primarily between 2 and 3 days . However there is an intersting trend where the hospitalixatio duration tends to increase with age, particularly after 60 year. this suggests that older individuals may, on averae require longer hospital datys compared to younge age groups.
# Asian Individuals tend to have hospital stays below th overall average until the age of 40 show an increase in hospital stays above th eaverage after 40 years, with an noticeable difference in the 60 to 80 age range.
# Hispanic Individuals generally stay around th average after 40 years and shoe significant difference in hospitalization duration for individuals in the 90 to 100 age range.
